# %% [markdown]
# # 01: Data Preprocessing
#
# **Student**: Keisuke Nishioka (Matrikelnummer: 10081049)
# **Project**: Stability and Faithfulness Analysis of SHAP Explanations

# %%
import sys
import os
sys.path.append('../src')

import pandas as pd
import numpy as np
from data_loader import load_adult_income, load_boston_housing, load_wine_quality, prepare_data
import config

# %% [markdown]
# ## Dataset Selection
#
# Choose one dataset for the analysis. We'll use Adult Income dataset as an example.

# %%
# Load dataset
X, y = load_adult_income()

print(f"Dataset shape: {X.shape}")
print(f"Number of features: {X.shape[1]}")
print(f"Number of samples: {X.shape[0]}")
print(f"Target distribution:\n{y.value_counts()}")

# %% [markdown]
# ## Data Preprocessing

# %%
# Prepare data: split and scale
X_train, X_test, y_train, y_test, scaler = prepare_data(
    X, y, test_size=0.2, random_state=42
)

print(f"Training set: {X_train.shape}")
print(f"Test set: {X_test.shape}")
print(f"Feature names: {list(X_train.columns[:5])}...")

# %% [markdown]
# ## Save Processed Data

# %%
# Save processed data
X_train.to_csv('../data/processed/X_train.csv', index=False)
X_test.to_csv('../data/processed/X_test.csv', index=False)
y_train.to_csv('../data/processed/y_train.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)

print("Data saved successfully!")
